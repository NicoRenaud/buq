# %%
import csv
with open("params.csv", "r") as f:
    reader = csv.DictReader(f)
    rows = list(reader)
print(rows)
# Out:
# [{'lengthscale': '0.75', 'acq_function': 'IVR', 'queries': '100', 'weight_acq_fes': '0.1', 'noise': '0.0', 'kernel_type': 'Matern52', 'full': 'False'}, {'lengthscale': '0.75', 'acq_function': 'US', 'queries': '100', 'weight_acq_fes': '0.1', 'noise': '0.0', 'kernel_type': 'Matern52', 'full': 'False'}, {'lengthscale': '0.5', 'acq_function': 'IVR', 'queries': '100', 'weight_acq_fes': '0.1', 'noise': '0.0', 'kernel_type': 'RBF', 'full': 'False'}, {'lengthscale': '0.5', 'acq_function': 'US', 'queries': '100', 'weight_acq_fes': '0.1', 'noise': '0.0', 'kernel_type': 'RBF', 'full': 'False'}, {'lengthscale': '0.6', 'acq_function': 'IVR', 'queries': '100', 'weight_acq_fes': '0.1', 'noise': '0.0', 'kernel_type': 'RBF', 'full': 'False'}, {'lengthscale': '0.6', 'acq_function': 'US', 'queries': '100', 'weight_acq_fes': '0.1', 'noise': '0.0', 'kernel_type': 'RBF', 'full': 'False'}, {'lengthscale': '0.75', 'acq_function': 'IVR', 'queries': '100', 'weight_acq_fes': '0.2', 'noise': '0.0', 'kernel_type
# ...

# %%
rows[]
# Out:
# {'lengthscale': '0.75',
#  'acq_function': 'IVR',
#  'queries': '100',
#  'weight_acq_fes': '0.1',
#  'noise': '0.0',
#  'kernel_type': 'Matern52',
#  'full': 'False'}
