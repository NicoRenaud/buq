# %%
import numpy as np
from buq.buq import ClassicalBayesianQuadratureMD
from buq.data.md import AlanineDipeptideMD
from buq.kernels.rbf import RBFKernel

# %%
target_function = AlanineDipeptideMD(mode='debug')

# %%
rbf = RBFKernel(lengthscale=0.75, noise=0.0)

# %%
x_data = target_function.generate_samples(10)
y_data = target_function(x_data)
# Out:
# Debug mode: Simulating MD run for phi=-1.4360623433985726, psi=1.0616525413259978
# Debug mode: Simulating MD run for phi=-1.1890993506034915, psi=1.1877164733022934
# Debug mode: Simulating MD run for phi=-3.138203340041149, psi=-0.8076731621518105
# Debug mode: Simulating MD run for phi=2.21858131748464, psi=-2.831078221948729
# Debug mode: Simulating MD run for phi=3.0075625447614973, psi=-1.3195452216131096
# Debug mode: Simulating MD run for phi=0.23123685232821245, psi=-2.0192736794329873
# Debug mode: Simulating MD run for phi=2.5117525451694647, psi=0.34800063994000885
# Debug mode: Simulating MD run for phi=-2.5040148794206356, psi=-1.6576425192817623
# Debug mode: Simulating MD run for phi=-1.4826376797519742, psi=2.457118952938849
# Debug mode: Simulating MD run for phi=-0.5219849913324683, psi=-0.9884181292517256

# %%
bq = ClassicalBayesianQuadratureMD(rbf, target_function)
# Out:
# Debug mode: Simulating MD run for phi=1.205928644867389, psi=-1.1879311005265074
# Debug mode: Simulating MD run for phi=3.0178957684121395, psi=2.3098095531770815
# Surrogate model initialized
#  /Users/renau001/Documents/projects/quantum/QuantumBayesianQuadrature/buq/.venv/lib/python3.11/site-packages/paramz/transformations.py:111: RuntimeWarning:divide by zero encountered in log

# %%
res = bq.run(10, plot_fit=True)
# Out:
#  -------------- BaysOpt loop, query 0 ---------------
# Debug mode: Simulating MD run for phi=-0.7853981633974483, psi=0.7853981633974478
#  -------------- BaysOpt loop, query 1 ---------------
# Debug mode: Simulating MD run for phi=-1.3089969389957472, psi=-1.3089969389957472
#  -------------- BaysOpt loop, query 2 ---------------
# Debug mode: Simulating MD run for phi=1.3089969389957465, psi=1.3089969389957465
#  -------------- BaysOpt loop, query 3 ---------------
# Debug mode: Simulating MD run for phi=-1.8325957145940461, psi=2.094395102393195
#  -------------- BaysOpt loop, query 4 ---------------
# Debug mode: Simulating MD run for phi=-2.356194490192345, psi=0.0
#  -------------- BaysOpt loop, query 5 ---------------
# Debug mode: Simulating MD run for phi=0.0, psi=-2.356194490192345
#  -------------- BaysOpt loop, query 6 ---------------
# Debug mode: Simulating MD run for phi=2.356194490192345, psi=0.0
#  -------------- BaysOpt loop, query 7 ---------------
# Debug mode: Simulating MD run for phi=0.0, psi=2.356194490192345
#  -------------- BaysOpt loop, query 8 ---------------
# Debug mode: Simulating MD run for phi=2.094395102393195, psi=-2.356194490192345
#  -------------- BaysOpt loop, query 9 ---------------
# Debug mode: Simulating MD run for phi=0.26179938779914913, psi=-0.2617993877991496

# %%
import matplotlib.pyplot as plt
plt.plot(res.rmse)
