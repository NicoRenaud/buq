# %%
import numpy as np

# %%
from buq.data.md import AlanineDipeptideMD
target_function = AlanineDipeptideMD(mode='debug')
# Out:
# /Users/renau001/Documents/projects/quantum/QuantumBayesianQuadrature/buq/.venv/lib/python3.11/site-packages/e3nn/o3/_wigner.py:10: UserWarning: Environment variable TORCH_FORCE_NO_WEIGHTS_ONLY_LOAD detected, since the`weights_only` argument was not explicitly passed to `torch.load`, forcing weights_only=False.
#   _Jd, _W3j_flat, _W3j_indices = torch.load(os.path.join(os.path.dirname(__file__), 'constants.pt'))
# cuequivariance or cuequivariance_torch is not available. Cuequivariance acceleration will be disabled.

# %%
from buq.kernels.rbf import RBFKernel

# %%
rbf = RBFKernel(lengthscale=0.75, noise=0.0)

# %%
x_data = target_function.generate_samples(10)
y_data = target_function(x_data)
print(x_data)
print(y_data)
# Out:
# Debug mode: Simulating MD run for phi=0.307274389741369, psi=1.1154483127039807
# Debug mode: Simulating MD run for phi=2.874178776290548, psi=-1.2192015200495714
# Debug mode: Simulating MD run for phi=2.782361743348094, psi=0.598536543663112
# Debug mode: Simulating MD run for phi=-2.7531820670764953, psi=-0.34962869551874176
# Debug mode: Simulating MD run for phi=2.8460892452446007, psi=-1.6160834232011603
# Debug mode: Simulating MD run for phi=-0.30359593407643937, psi=-1.582147764247692
# Debug mode: Simulating MD run for phi=-0.5515559946835307, psi=2.3134049870409124
# Debug mode: Simulating MD run for phi=-1.282427312701365, psi=-2.5142653057410573
# Debug mode: Simulating MD run for phi=-1.9437560096756363, psi=-2.720283274281819
# Debug mode: Simulating MD run for phi=1.7203863517268259, psi=0.07307533356270479
# [[ 0.30727439  1.11544831]
#  [ 2.87417878 -1.21920152]
#  [ 2.78236174  0.59853654]
#  [-2.75318207 -0.3496287 ]
#  [ 2.84608925 -1.61608342]
#  [-0.30359593 -1.58214776]
#  [-0.55155599  2.31340499]
#  [-1.28242731 -2.51426531]
#  [-1.94375601 -2.72028327]
#  [ 1.72038635  0.07307533]]
# [[  6.82896455   5.05982214]
#  [  3.23254219   4.54943603]
#  [-18.44867182  -7.09727344]
#  [ 10.34879956   6.05421626]
#  [  2.25939756   3.6255367 ]
#  [ -3.58087113  -4.73672842]
#  [ -1.55883237   1.77290157]
#  [  0.66230056  -1.94729523]
#  [ -0.95792463   2.91773124]
#  [  6.26053516   3.79257044]]

# %%
bounds = target_function.parameter_space.get_bounds()
# bounds = [d[0] for d in bounds], [d[1] for d in bounds]
print(bounds)
# Out:
# [(-3.141592653589793, 3.141592653589793), (-3.141592653589793, 3.141592653589793)]

# %%
rbf.get_kernel(x_data, y_data, bounds=bounds)
# Out:
#  /Users/renau001/Documents/projects/quantum/QuantumBayesianQuadrature/buq/.venv/lib/python3.11/site-packages/paramz/transformations.py:111: RuntimeWarning:divide by zero encountered in log

# %%
from buq.buq import ClassicalBayesianQuadratureMD

# %%
bq = ClassicalBayesianQuadratureMD(rbf, target_function)
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =          100     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.52110D+01    |proj g|=  6.34787D-01
#
# At iterate   10    f=  6.85924D+00    |proj g|=  7.48246D-03
#  This problem is unconstrained.
# At iterate   20    f=  6.81393D+00    |proj g|=  5.84155D-04
#
# At iterate   30    f=  6.81386D+00    |proj g|=  5.11591D-05
# Debug mode: Simulating MD run for phi=-2.8656919599200052, psi=3.1397989860503133
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#   100     32     36      1     0     0   6.661D-06   6.814D+00
#   F =   6.8138587468487257
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# Debug mode: Simulating MD run for phi=3.027817923537887, psi=2.6475357081566697
